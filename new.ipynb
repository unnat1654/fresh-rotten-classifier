# %%
import pickle
import pandas as pd

# %%
classifier=pickle.load(open("freshRottenClassifier.sav","rb"))

# %%
df=pd.read_csv("processedData.csv")

# %%
df
# Out:
#              c0        c1        c2        c3        c4        c5        c6  \
# 0      1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1      1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2      1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 3      1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 4      0.992157  0.992157  0.968627  0.992157  0.992157  0.968627  0.996078
# ...         ...       ...       ...       ...       ...       ...       ...
# 16501  0.980392  0.980392  0.980392  0.980392  0.980392  0.980392  0.980392
# 16502  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 16503  0.984314  0.984314  0.984314  0.984314  0.984314  0.984314  0.984314
# 16504  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16505  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
# ...

# %%
[ans]=classifier.predict(df.head(1))
ans
# Out:
# 1

# %%
df.shape
# Out:
# (16506, 3888)
